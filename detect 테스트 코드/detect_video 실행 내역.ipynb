# %%
# !python3 detect_video3_colorhsv_improved.py --use_custom True #--export_video_frame =True # #782
# Out:
# Namespace(batch_size=1, class_path='data/custom/classes.names', conf_thres=0.5, export_video_frame=False, image_folder='data/sample_videos/sample', img_size=416, model_def='config/yolov4-custom.cfg', n_cpu=0, nms_thres=0.4, use_custom=True, weights_path='weights/custom/yolov4_custom_0.629.pth')
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:00.217588
# 	+ Batch 1, Inference Time: 0:00:00.207375
# 	+ Batch 2, Inference Time: 0:00:00.186751
# 	+ Batch 3, Inference Time: 0:00:00.116874
# 	+ Batch 4, Inference Time: 0:00:00.202707
# 	+ Batch 5, Inference Time: 0:00:00.155582
# 	+ Batch 6, Inference Time: 0:00:00.153562
# 	+ Batch 7, Inference Time: 0:00:00.214746
# 	+ Batch 8, Inference Time: 0:00:00.233184
# 	+ Batch 9, Inference Time: 0:00:00.223902
# 	+ Batch 10, Inference Time: 0:00:00.177016
# 	+ Batch 11, Inference Time: 0:00:00.158422
# 	+ Batch 12, Inference Time: 0:00:00.259844
# 	+ Batch 13, Inference Time: 0:00:00.186324
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 4))
plt.margins(0.1, 0.1)
for x in range(0, 8):
    for y in range(0, 4):
        plt.scatter(x, y, c='b')
        plt.text(x+0.1, y, "point({}, {})".format(x, y), fontsize=100)
        plt.show()
